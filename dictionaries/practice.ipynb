# %%
Goal: Make a dictionary person with keys "name", "age", "city". Print the name.
Example: {"name":"Rishi","age":27,"city":"Bangalore"} → prints Rishi
Hint: person["name"]

# %%
person = {"name":"rishi", "age":"29", "city":"palampur"}
print(person['name'])
# Out:
# rishi

# %%
d = {"a":1}
print(d.get("b",0))
# Out:
# 0

# %%
d = {}
d["x"]=10
d["x"] +=5
print(d['x'])
# Out:
# 15

# %%
person = {"name":"rishi", "age":"29", "city":"palampur"}
person.pop("age")
print(person)
# Out:
# {'name': 'rishi', 'city': 'palampur'}
