# %%
empty_dict = {}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
student = {"name": "Alice", "age": 21, "major": "Computer Science"}
print(student)
print(type(student))
# Out:
# {'name': 'Alice', 'age': 21, 'major': 'Computer Science'}
# <class 'dict'>

# %%
## single key allowed only with one name 
student = {"name": "Alice", "age": 21, "major": "Computer Science", "age":32}
print(student)
print(student['age'])
# Out:
# {'name': 'Alice', 'age': 32, 'major': 'Computer Science'}
# 32

# %%
student(['age'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 student(['age'])
#
# TypeError: 'dict' object is not callable

# %%
print(student['age'])
# Out:
# 32

# %%
print(student["name"])  # Outputs: Alice
# Out:
# Alice

# %%
scores = {"Jane Doe": 90, "John Smith": 86, "Alice Adams": 93}
print(scores["Jane Doe"]) # Outputs: 90
# Out:
# 90
