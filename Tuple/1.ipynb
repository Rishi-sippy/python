# %%
empty_tuple=()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
tpl =tuple()
print(type(tpl))
# Out:
# <class 'tuple'>

# %%
mixed_tuple=(1,"Hi", 3.45, True)
print(mixed_tuple)
# Out:
# (1, 'Hi', 3.45, True)

# %%
numbers = (1,2,3,4,5,67,8,9)
print(numbers[-1])
# Out:
# 9

# %%
# Examples of tuples
t1 = (1, 2, 3)
t2 = ("apple", "banana", "cherry")
t3 = (1, "hello", 3.14, True)

# %%
t4 = 1, 2, 3

# %%
t5 = (5,)   # This is a tuple
not_tuple = (5)   # This is just an integer

# %%
t = (10, 20, 30, 40)
print(t[0])   # 10
print(t[-1])  # 40
# Out:
# 10
# 40

# %%
print(t[1:3])
# Out:
# (20, 30)

# %%
t = (1, 2, 3)
t = (1, 2, 3)

# t[0] = 10   # ❌ This will raise a TypeError?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 t = (1, 2, 3)
#       2 t = (1, 2, 3)
# ----> 3 t[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Concatenation
t1 = (1, 2)
t2 = (3, 4)
t3 = t1 + t2  # (1, 2, 3, 4)

# Repetition
t4 = t1 * 3   # (1, 2, 1, 2, 1, 2)

# Membership test
print(2 in t1)  # True
# Out:
# True

# %%
person = ("Alice", 25, "Engineer")
name, age, job = person

print(name)  # Alice
print(age)   # 25
# Out:
# Alice
# 25

# %%
numbers * 3
# Out:
# (1, 2, 3, 4, 5, 67, 8, 9, 1, 2, 3, 4, 5, 67, 8, 9, 1, 2, 3, 4, 5, 67, 8, 9)

# %%
mixed_tuple * 3
# Out:
# (1, 'Hi', 3.45, True, 1, 'Hi', 3.45, True, 1, 'Hi', 3.45, True)

# %%
numbers
# Out:
# (1, 2, 3, 4, 5, 67, 8, 9)

# %%
print(numbers.count(1))
print(numbers.index(4))
# Out:
# 1
# 3

# %%
mixed_tuple
# Out:
# (1, 'Hi', 3.45, True)

# %%
a,b,c,d = mixed_tuple

# %%
print(a)
print(b)
print(c)
print(d)
# Out:
# 1
# Hi
# 3.45
# True

# %%
first, *center, last = mixed_tuple
print(first)
print(center)
print(last)
# Out:
# 1
# ['Hi', 3.45]
# True

# %%
lst = [[1,2,3,4,5],[6,7,8,9,],["how are you", "my, buddy"],[5.2, True]]
print(lst)
# Out:
# [[1, 2, 3, 4, 5], [6, 7, 8, 9], ['how are you', 'my, buddy'], [5.2, True]]

# %%
lst[0][1:4]
# Out:
# [2, 3, 4]

# %%
nested_tuple = ((1,2,3),("a","b","c"), (True,False))
for sub_tuple in nested_tuple:
  for item in sub_tuple:
    print(item, end = ' ')
  print()
# Out:
# 1 2 3
# a b c
# True False

# %%
grades = [56,66, 78,88, 92,99]
print(grades)
print(type(grades))
print(max(grades))
# Out:
# [56, 66, 78, 88, 92, 99]
# <class 'list'>
# 99

# %%
fruits = ["Apple", "Orange", "Gauva", "Pomegrenate"]
fruits.append("Graps")
print(fruits)
print(fruits[3])
# Out:
# ['Apple', 'Orange', 'Gauva', 'Pomegrenate', 'Graps']
# Pomegrenate
