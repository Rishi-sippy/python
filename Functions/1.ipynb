# %%
def checkNum(num):
  if num%2==0:
    print("num is even")
  else:
    print("num is odd")
checkNum(23)
# Out:
# num is odd

# %%
def greet():
  print("Hello World")
greet()
# Out:
# Hello World

# %%
def greet(name):
  print(f"Hi, {name}!")
greet('Rishi')
# Out:
# Hi, Rishi!

# %%
def add (a,b):
  return a+b
result = add(5,3)
print(result)
# Out:
# 8
