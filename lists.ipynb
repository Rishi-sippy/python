# %%
lst=[]
print(type(lst))
# Out:
# <class 'list'>

# %%
names = ["Rishi", "Ajay", "Akshay", 1,2,3,4,5]
print(names)
# Out:
# ['Rishi', 'Ajay', 'Akshay', 1, 2, 3, 4, 5]

# %%
names = ["Rishi", "Ajay", "Akshay"]
print(names[1])
print(names[-1])
print(names[1:2])
# Out:
# Ajay
# Akshay
# ['Ajay']

# %%
names
# Out:
# ['Rishi', 'Ajay', 'Akshay']

# %%
names[2]
# Out:
# 'Akshay'

# %%
names[1]='Arvind'

# %%
names
# Out:
# ['Rishi', 'Arvind', 'Akshay']

# %%
names.append("Ajay")

# %%
names
# Out:
# ['Rishi', 'Arvind', 'Akshay', 'Ajay']

# %%
names.insert(-1, 'Rajeev')
names
# Out:
# ['Rishi', 'Arvind', 'Akshay', 'Rajeev', 'Ajay']

# %%
names.remove("Rajeev")
names
# Out:
# ['Rishi', 'Arvind', 'Akshay', 'Ajay']

# %%
names.pop()
# Out:
# 'Ajay'

# %%
names
# Out:
# ['Rishi', 'Arvind', 'Akshay']
